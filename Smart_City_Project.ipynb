# %% [markdown]
# <a href="https://colab.research.google.com/github/Ishita95-harvad/sMART-CITY-PROJECT/blob/main/Smart_City_Project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # SMART CITY PROJECT HARYANA
# **Water Revenue Data Karnal 2013 2018**
#
# Here is all the data you need:
#
# "D10-WaterTax_8_1.csv"

# %% [markdown]
# ## Data loading
#
# ### Subtask:
# Load the dataset "D10-WaterTax_8_1.csv" into a pandas DataFrame.

# %% [markdown]
# **Reasoning**:
# Load the dataset "D10-WaterTax_8_1.csv" into a pandas DataFrame and display the first 5 rows and the shape of the DataFrame.

# %%
import pandas as pd

try:
    df = pd.read_csv('D10-WaterTax_8_1.csv')
    display(df.head())
    print(df.shape)
except FileNotFoundError:
    print("Error: 'D10-WaterTax_8_1.csv' not found.")
    df = None
except pd.errors.ParserError:
    print("Error: Could not parse the CSV file.")
    df = None
except Exception as e:
    print(f"An unexpected error occurred: {e}")
    df = None
# Out:
#   City Name  Zone Name  Ward Name  Ward No.  \
# 0    KARNAL        NaN        NaN       NaN
#
#    Water tax billed (in INR lakhs)-Total-2013-14  \
# 0                                       19526498
#
#    Water tax billed (in INR lakhs)-Commercial-2013-14  \
# 0                                                NaN
#
#    Water tax billed (in INR lakhs)-Residential-2013-14  \
# 0                                                NaN
#
#    Water tax billed (in INR lakhs)-Total-2014-15  \
# 0                                       18950898
#
#    Water tax billed (in INR lakhs)-Commercial-2014-15  \
# 0                                                NaN
#
#    Water tax billed (in INR lakhs)-Residential-2014-15  ...  \
# 0                                                NaN    ...
#
#    Water tax collected (in INR lakhs)-Residential-2014-15  \
# 0                                                NaN
#
#    Water tax collected (in INR lakhs)-Total-2015-16  \
# ...

# %% [markdown]
# ## Data exploration
#
# ### Subtask:
# Explore the loaded dataset to understand its characteristics.

# %% [markdown]
# **Reasoning**:
# Analyze the dataset by examining its shape, data types, missing values, descriptive statistics, distributions, and potential outliers.

# %%
import matplotlib.pyplot as plt

# ... (previous code for shape, data types, and missing values)

# Descriptive statistics for numerical columns
numerical_cols = df.select_dtypes(include=['number'])
print("\nDescriptive Statistics for Numerical Columns:\n", numerical_cols.describe())

# Analyze the distribution of key variables (corrected layout)
plt.figure(figsize=(15, 30))  # Increased figure size to accommodate all histograms
for i, col in enumerate(numerical_cols.columns):
    plt.subplot(11, 3, i + 1) # Adjusted subplot layout to prevent ValueError
    df[col].plot(kind='hist', bins=20)
    plt.title(col)
plt.tight_layout()
plt.show()

# ... (rest of the code)
# Out:
# Descriptive Statistics for Numerical Columns:
#         Zone Name  Ward Name  Ward No.  \
# count        0.0        0.0       0.0
# mean         NaN        NaN       NaN
# std          NaN        NaN       NaN
# min          NaN        NaN       NaN
# 25%          NaN        NaN       NaN
# 50%          NaN        NaN       NaN
# 75%          NaN        NaN       NaN
# max          NaN        NaN       NaN
#
#        Water tax billed (in INR lakhs)-Total-2013-14  \
# count                                            1.0
# mean                                      19526498.0
# std                                              NaN
# min                                       19526498.0
# 25%                                       19526498.0
# 50%                                       19526498.0
# 75%                                       19526498.0
# max                                       19526498.0
#
#        Water tax billed (in INR lakhs)-Commercial-2013-14  \
# ...

# %% [markdown]
# **Reasoning**:
# The previous code block failed due to an incorrect layout for the histograms.  I will modify the code to correct the layout and rerun the analysis.  The boxplot code will also be adjusted to handle the single-row nature of the dataset more gracefully.

# %%
import matplotlib.pyplot as plt

# ... (previous code for shape, data types, and missing values)

# Descriptive statistics for numerical columns
numerical_cols = df.select_dtypes(include=['number'])
print("\nDescriptive Statistics for Numerical Columns:\n", numerical_cols.describe())

# Analyze the distribution of key variables (corrected layout)
plt.figure(figsize=(15, 30))  # Increased figure size to accommodate all histograms
for i, col in enumerate(numerical_cols.columns):
    plt.subplot(11, 3, i + 1) # Adjusted subplot layout to prevent ValueError
    df[col].plot(kind='hist', bins=20)
    plt.title(col)
plt.tight_layout()
plt.show()

# Identify potential outliers using box plots
plt.figure(figsize=(10, 6))
# Check if there are numerical columns and handle the case where there are none or just one
if not numerical_cols.empty:
    # Convert numerical_cols.columns to a list of strings
    columns_to_plot = [col[0] if isinstance(col, tuple) else col for col in numerical_cols.columns]
    # Only include columns that actually exist in the original DataFrame
    valid_columns = [col for col in columns_to_plot if col in df.columns]

    # Now use the valid columns for boxplot if there are any:
    if valid_columns:
        df.boxplot(column=valid_columns, rot=90)
        plt.title('Box Plots of Numerical Columns')
        plt.tight_layout()
        plt.show()
    else:
        print("No valid numerical columns to generate box plots.") # Handle the case of no valid columns
else:
    print("No numerical columns to generate box plots.")

# Summarize key findings and suggest data cleaning steps
print("\nSummary and Data Cleaning Suggestions:")
print("The dataset contains one row and 34 columns, the majority of the columns have missing values.")
print("Most of the columns are numerical, representing water tax billed and collected amounts across different years and categories.")
print("Given there's only one row of data, standard imputation techniques are not suitable.")
print("The dataset's utility for analysis is extremely limited. More data is needed to draw meaningful conclusions or to train models.")
# Out:
# Descriptive Statistics for Numerical Columns:
#         Zone Name  Ward Name  Ward No.  \
# count        0.0        0.0       0.0
# mean         NaN        NaN       NaN
# std          NaN        NaN       NaN
# min          NaN        NaN       NaN
# 25%          NaN        NaN       NaN
# 50%          NaN        NaN       NaN
# 75%          NaN        NaN       NaN
# max          NaN        NaN       NaN
#
#        Water tax billed (in INR lakhs)-Total-2013-14  \
# count                                            1.0
# mean                                      19526498.0
# std                                              NaN
# min                                       19526498.0
# 25%                                       19526498.0
# 50%                                       19526498.0
# 75%                                       19526498.0
# max                                       19526498.0
#
#        Water tax billed (in INR lakhs)-Commercial-2013-14  \
# ...

# %% [markdown]
# **Reasoning**:
# The boxplot code still failed due to an issue with indexing and the single-row nature of the dataframe. I will remove the boxplot code entirely since it's not meaningful with only one data point, and I will adjust the summary to reflect the lack of useful information from the single data point.

# %% [markdown]
# ## Data cleaning
#
# ### Subtask:
# Clean the data by handling missing values and removing duplicates (if any).

# %% [markdown]
# **Reasoning**:
# Document the decisions on handling missing values and duplicates, given the dataset contains only one row.

# %%
print("Data Cleaning Summary:")
print("\n1. Missing Value Handling:")
print("   - The dataset contains only one row. Standard imputation methods are not applicable.")
print("   - Given the extremely limited data, any imputation would be highly unreliable and potentially misleading.")
print("   - The decision is to document the extensive missingness and acknowledge its impact on any subsequent analysis.")
print("   - No modifications will be made to the dataframe regarding missing values.")

print("\n2. Duplicate Removal:")
print("   - The dataset contains only one row, thus there cannot be any duplicate rows.")
print("   - No duplicate row removal will be performed.")

print("\n3. Overall Summary:")
print("   - The single data point severely limits any data cleaning and analysis.  More data is essential for meaningful insights.")
# Out:
# Data Cleaning Summary:
#
# 1. Missing Value Handling:
#    - The dataset contains only one row. Standard imputation methods are not applicable.
#    - Given the extremely limited data, any imputation would be highly unreliable and potentially misleading.
#    - The decision is to document the extensive missingness and acknowledge its impact on any subsequent analysis.
#    - No modifications will be made to the dataframe regarding missing values.
#
# 2. Duplicate Removal:
#    - The dataset contains only one row, thus there cannot be any duplicate rows.
#    - No duplicate row removal will be performed.
#
# 3. Overall Summary:
#    - The single data point severely limits any data cleaning and analysis.  More data is essential for meaningful insights.

# %% [markdown]
# ## Data wrangling
#
# ### Subtask:
# Transform the data in the DataFrame `df` to prepare it for analysis and visualization, considering the limitations of a single data point.

# %% [markdown]
# **Reasoning**:
# Analyze data types, handle inconsistencies, and document potential feature engineering, then perform necessary data type conversions based on the analysis.  Since there's only one row, the analysis will focus on potential issues if more data were available.

# %%
# Examine Data Types and Inconsistent Representations
print("Data Type Examination and Inconsistency Check:")
for col in df.columns:
    print(f"- Column '{col}':")
    print(f"  - Current Data Type: {df[col].dtype}")
    # Check for potential type conversion needs (if more data existed)
    if pd.api.types.is_numeric_dtype(df[col]):
      print("  - Potential Type Conversion: No conversion appears necessary if more data is numeric.")
    elif pd.api.types.is_string_dtype(df[col]):
      print("  - Potential Type Conversion: Check for consistent formatting and consider converting to numeric or categorical if applicable in a larger dataset.")
    else:
      print("  - Potential Type Conversion: Further investigation needed with more data.")
    # Check for potential inconsistencies (if more data existed)
    print(f"  - Potential Inconsistencies: In a larger dataset, check for variations in capitalization, spacing, and abbreviations.")


# Feature Engineering (Documentation Only)
print("\nPotential Feature Engineering (with more data):")
print("- Ratio of water tax billed to collected amounts for each category (Commercial/Residential) and year.")
print("- Year-over-year change in water tax billed and collected amounts.")
print("- Aggregated values (sum, mean, etc.) of water tax billed and collected across different zones, wards, and years.")
print("- Create indicators for different tax status (e.g., 'Fully Paid', 'Partially Paid', 'Overdue').")

# Data Type Conversion (if necessary)
# Based on the single row, no conversion is immediately necessary.
# However, with more rows, the following would need to be addressed:
#   - Convert relevant columns to numeric types after cleaning (e.g., removing non-numeric characters).
#   - Convert other columns to categorical types (e.g., city, zone, ward) for better analysis.


print("\nData Type Conversion (if more data were available):")
print("  - After examining the dataset with multiple rows, the data types of columns like 'Water tax billed' and 'Water tax collected' would need conversion from object to numeric.  This would likely involve cleaning non-numeric characters if present in the data.")
print("  - The columns representing geographic information ('City Name', 'Zone Name', 'Ward Name') would likely be converted to categorical types to allow for more efficient and meaningful analysis.")
# Out:
# Data Type Examination and Inconsistency Check:
# - Column 'City Name':
#   - Current Data Type: object
#   - Potential Type Conversion: Check for consistent formatting and consider converting to numeric or categorical if applicable in a larger dataset.
#   - Potential Inconsistencies: In a larger dataset, check for variations in capitalization, spacing, and abbreviations.
# - Column 'Zone Name':
#   - Current Data Type: float64
#   - Potential Type Conversion: No conversion appears necessary if more data is numeric.
#   - Potential Inconsistencies: In a larger dataset, check for variations in capitalization, spacing, and abbreviations.
# - Column 'Ward Name':
#   - Current Data Type: float64
#   - Potential Type Conversion: No conversion appears necessary if more data is numeric.
#   - Potential Inconsistencies: In a larger dataset, check for variations in capitalization, spacing, and abbreviations.
# - Column 'Ward No.':
#   - Current Data Type: float64
# ...

# %% [markdown]
# ## Data analysis
#
# ### Subtask:
# Analyze the cleaned and wrangled data to gain insights.  Due to the single row of data, this will involve documenting potential analyses that could be performed with a larger dataset.

# %% [markdown]
# **Reasoning**:
# Generate the analysis report based on the provided data and instructions.

# %%
print("Analysis of Water Tax Data (Potential with Larger Dataset)")
print("-" * 50)

print("\n1. Descriptive Statistics (Potential):")
print("With a larger dataset, descriptive statistics (mean, median, standard deviation, quartiles, min, max) would be calculated for numerical columns like 'Water tax billed' and 'Water tax collected' for each year and category (total, commercial, residential).  These statistics would reveal the central tendency, dispersion, and skewness of the tax amounts. For example, a high standard deviation for water tax billed in a specific year would suggest a wide range of tax amounts across different zones or wards.")

print("\n2. Correlation Analysis (Potential):")
print("Correlation analysis (Pearson or Spearman) could explore relationships between 'Water tax billed' and 'Water tax collected' across different years and categories. A strong positive correlation would indicate that higher billed amounts are associated with higher collected amounts.  A correlation matrix would provide a visual representation of these relationships.  This would help understand the efficiency of tax collection and identify potential discrepancies or trends.")

print("\n3. Group-wise Analysis (Potential):")
print("The data could be analyzed by geographic location (City Name, Zone Name, Ward Name) or by year. For instance, the mean water tax amount could be calculated for each city or zone, helping to identify areas with higher or lower tax burdens.  Bar charts or box plots could visualize these differences, highlighting potential disparities in tax collection or tax burden across different regions.  This would help decision-makers to allocate resources or adjust policies accordingly.")

print("\n4. Time Series Analysis (Potential):")
print("Time series analysis would examine trends in water tax billed and collected amounts over the years. Line plots would visually represent these trends. Techniques like moving averages or smoothing methods would help to reveal cyclical patterns or long-term trends.  For example, an increasing trend in the ratio of collected to billed amounts might indicate improvement in collection efficiency.  This would inform resource allocation and help policymakers to predict future tax revenues.")


print("\n5. Summary and Insights (Required):")
print("With a larger, more comprehensive dataset, these analyses could provide valuable insights into water tax collection efficiency, identify areas with high/low tax burdens, and reveal temporal trends. This information would be crucial for making data-driven decisions regarding resource allocation, tax policy adjustments, and improved service delivery.  No actual calculations or visualizations are performed due to the dataset's single data row.")
# Out:
# Analysis of Water Tax Data (Potential with Larger Dataset)
# --------------------------------------------------
#
# 1. Descriptive Statistics (Potential):
# With a larger dataset, descriptive statistics (mean, median, standard deviation, quartiles, min, max) would be calculated for numerical columns like 'Water tax billed' and 'Water tax collected' for each year and category (total, commercial, residential).  These statistics would reveal the central tendency, dispersion, and skewness of the tax amounts. For example, a high standard deviation for water tax billed in a specific year would suggest a wide range of tax amounts across different zones or wards.
#
# 2. Correlation Analysis (Potential):
# ...

# %% [markdown]
# ## Data visualization
#
# ### Subtask:
# Visualize the key findings from the data analysis, acknowledging the limitations of the single data point.

# %% [markdown]
# **Reasoning**:
# Create visualizations to show the limitations of the single data point, including a bar chart of missing values and bar charts for categorical columns. Add a summary section to describe the visualizations and insights (or lack thereof).

# %%
import matplotlib.pyplot as plt

# Missing Value Visualization
plt.figure(figsize=(12, 6))
missing_values = df.isnull().sum()
plt.bar(missing_values.index, missing_values.values, color='skyblue')
plt.xlabel("Columns", fontsize=12)
plt.ylabel("Number of Missing Values", fontsize=12)
plt.title("Missing Values per Column", fontsize=14)
plt.xticks(rotation=90)
plt.tight_layout()
plt.show()

# Categorical data visualization
categorical_columns = ['City Name', 'Zone Name', 'Ward Name']
plt.figure(figsize=(15, 5))
for i, col in enumerate(categorical_columns):
    plt.subplot(1, len(categorical_columns), i + 1)
    if df[col].notnull().any():  # Check if the column is not entirely NaN
      df[col].value_counts().plot(kind='bar', color=['lightcoral', 'lightgreen', 'lightsteelblue'])
      plt.xlabel(col, fontsize=10)
      plt.ylabel("Count", fontsize=10)
      plt.title(f"Unique Values in '{col}'", fontsize=12)
      plt.xticks(rotation=45, ha='right')
      plt.tight_layout()
    else:
      plt.text(0.5, 0.5, f"All values in '{col}' are missing", ha='center', va='center')
      plt.xticks([])
      plt.yticks([])
      plt.title(f"Unique Values in '{col}'", fontsize=12)


plt.show()


print("Visualization Summary:")
print("Due to the single data point, the visualization does not represent a true distribution. Standard methods like histograms and boxplots are not meaningful for one datapoint.")
print("The bar chart showing missing values gives a clear picture of the missing values per column, but is not a statistical distribution in this context.")
print("Bar plots created for categorical columns show the unique value and its counts.  Again, these cannot represent distributions.")
print("More data is needed to perform meaningful analysis.")
# Out:
# Visualization Summary:
# Due to the single data point, the visualization does not represent a true distribution. Standard methods like histograms and boxplots are not meaningful for one datapoint.
# The bar chart showing missing values gives a clear picture of the missing values per column, but is not a statistical distribution in this context.
# Bar plots created for categorical columns show the unique value and its counts.  Again, these cannot represent distributions.
# More data is needed to perform meaningful analysis.

# %% [markdown]
# ## Summary:
#
# ### 1. Q&A
#
# No questions were explicitly asked in the provided data analysis task. However, the analysis implicitly addresses the question of how to analyze a dataset with only one row.
#
#
# ### 2. Data Analysis Key Findings
#
# *   The dataset contains only one row and 34 columns, severely limiting the scope of analysis.  Standard statistical analyses are not meaningful.
# *   Most columns contain missing values.  Imputation is not appropriate given the limited data, as it would introduce bias.
# *   No duplicate rows exist due to the dataset's size.
# *   Potential feature engineering opportunities (ratios, year-over-year changes, aggregations) were identified for a larger dataset.
# *   The analysis visually demonstrated the number of missing values in each column.
#
#
# ### 3. Insights or Next Steps
#
# *   The current dataset provides no meaningful insights.  More data is crucial for any meaningful analysis, feature engineering, or model training.
# *   Gather additional data to expand the dataset and enable meaningful statistical analysis, modeling, and visualization.
